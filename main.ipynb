# %% [markdown]
# This is a Jupyter Notebook file. Use this instead of main.py for graphing functions (so the output can be saved inside the ipynb file).
#
# VS Code's Terminal can only support "expressions over a 1D range". Thus use matplotlib ( pip install matplotlib ).

# %%
import matplotlib.pyplot as plt
from sympy import plot_implicit, symbols, Eq, And

x, y = symbols('x y')
p1 = plot_implicit(Eq(x**2 + y**2, 5), backend='matplotlib')
plt.show()
